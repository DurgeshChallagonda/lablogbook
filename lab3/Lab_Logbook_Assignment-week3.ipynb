# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
data = pd.read_csv('telecom_churn.csv')
Clr = data['Churn'].map({False:'blue',True:'orange'})
fig = plt.figure(figsize=(11,7))
plt.scatter(data['Total intl calls'], data['Total day charge'], color = Clr);
plt.xlabel('International calls');
plt.ylabel('Day charge');
plt.show();
